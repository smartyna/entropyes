# %%
sorting_extractor = se.MdaSortingExtr0klo[udy = 'paired_kampff'
plotbin_size = 10
import spikeextractors as se
import kachery as ka
ka.set_config(fr='default_readonly')
import sys, time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.neighbors import KernelDensity
from pyentropy import DiscreteSystem
import scipy.stats as stats
SF = ka.load_object('sha1://1667383039f1170256e4e3445d46eff367e202e5/output.json', fr='default_readonly')
sorting_results = SF['SortingResults']
len(sorting_results[0]),len(sorting_results)
firings_path = ka.load_file(sorting_results[0]['firings'])
sorting = sorting_extractor(firings_path)
ii = []
for i in sorting_results:
    ii.append(i['studyName'])
ii = np.array(ii)

def calculate_entropies_counts(sorting, method, sampling_frequency, binSec=0.5):
    output = np.zeros((len(sorting.get_unit_ids())))

    sampF = sampling_frequency
    unit_ids = sorting.get_unit_ids()
    fr = np.zeros(len(unit_ids))
    isi = [[] for uid in unit_ids]
    spike_trains = [sorting.get_unit_spike_train(unit_id=uid) for uid in unit_ids]
    maxT = np.max([np.max(st) for st in spike_trains]) / sampling_frequency
    for ii, unit_id in enumerate(unit_ids):
        spk = spike_trains[ii]
        fr[ii] = len(spk)/maxT
        isi[ii] = np.diff(spk)/sampF
        binSize = binSec * sampF 
        bins = np.arange(0, maxT*sampF, binSize)
        spkCount,_ = np.histogram(spk, bins)

        xm = np.max(spkCount)+1
        sys = DiscreteSystem(spkCount.astype(int), (1,xm), spkCount, (1,xm))        
        if method == 'plugin':
            sys.calculate_entropies(method='plugin', calc=['HX'])
            output[ii] = sys.H_plugin['HX']
        elif method == 'pt':
            sys.calculate_entropies(method='pt', calc=['HX'])
            output[ii] = sys.H_pt['HX']
        elif method == 'qe':
            sys.calculate_entropies(method='qe', calc=['HX'])
            output[ii] = sys.H_qe['HX']
        #elif method == 'CDM':
            #output[ii] = eng.entropyCDM(matlab.double(spkCount.tolist()), 0)
    return output, fr, isi

def poisson_spk_entropy(fr,binSec,N):
    x = np.random.poisson(fr*binSec,N)
    xm = np.max(x)+1
    sys = DiscreteSystem(x.astype(int), (1,xm), x, (1,xm))
    sys.calculate_entropies(method='pt', calc=['HX'])
    return sys.H_pt['HX']

def run_poisson_spkH_samples(fr,binSec,N,R):
    out = np.zeros(R)
    for r in range(R):
        out[r] = poisson_spk_entropy(fr,binSec,N)
    return np.mean(out)

sorters_ = []; recs = []
for i in sorting_results:
    if i['studyName']==ref_study:
        sorters_.append(i['sorterName'])
        recs.append(i['recordingName'])
sorters_ = np.asarray(sorters_)
sorters = np.unique(sorters_)   
recs_names = np.unique(recs)

output_sort_c = {} #dictionary with all the H/unit per recording, for all of the sorters and all of the recordings (but chosen bias estimator)
bias = ['pt'] #list - better
FR_c = {}; ISI_c = {}
for y in bias:
    all_methods = {k:{} for k in sorters}
    fr = {k:{} for k in sorters}
    isi = {k:{} for k in sorters}
    for k in sorters:
        all_methods[k] = {kk:[] for kk in recs_names}
        fr[k] = {kk:[] for kk in recs_names}
        isi[k] = {kk:[] for kk in recs_names}
    for x in range(len(sorting_results)):
        if sorting_results[x]['studyName']==ref_study:
            try:
                firings_path = ka.load_file(sorting_results[x]['firings'])
                sort_temp = sorting_results[x]['sorterName']
                rec_temp = sorting_results[x]['recordingName']
                sorting = sorting_extractor(firings_path)
                all_methods[sort_temp][rec_temp], fr[sort_temp][rec_temp], isi[sort_temp][rec_temp] =\
                    calculate_entropies_counts(sorting, method=y, sampling_frequency=30000,
                                       binSec=0.5)
            except:
                a=1
    output_sort_c[y]= all_methods
    FR_c[y] = fr; ISI_c[y] = isi

HF_counts = {} #dictionary with normalised H/unit per recording, for all of the sorters and all of the recordings (but chosen bias estimator)
bias = ['pt'] #list - better
binL = 0.5

for y in bias:
    temp_out = {k:{} for k in sorters}
    for k in sorters:
        temp_out[k] = {kk:[] for kk in recs_names}
    for x in range(len(sorting_results)):
        if sorting_results[x]['studyName']==ref_study:
            try:
                firings_path = ka.load_file(sorting_results[x]['firings'])
                sort_temp = sorting_results[x]['sorterName']
                rec_temp = sorting_results[x]['recordingName']
                sorting = sorting_extractor(firings_path)
                for i in range(len(output_sort_c[y][sort_temp][rec_temp])):
                    nSpike = len(ISI_c[y][sort_temp][rec_temp][i])+1;
                    FR_spk = FR_c[y][sort_temp][rec_temp][i];
                    H_poiss = run_poisson_spkH_samples(FR_spk,binL,nSpike,10)                    
                    temp_out[sort_temp][rec_temp].append(output_sort_c[y][sort_temp][rec_temp][i]/H_poiss)                                        
            except:
                a=1
    HF_counts[y] = temp_out
    
def hamming(ST1,ST2):
    output=0
    if len(ST1)!=len(ST2):
        print("Spike trains are not equal")
    else:
        for x,(i,j) in enumerate(zip(ST1,ST2)):
            if i!=j:
                print(f'char not math{i,j}in {x}')
                output+=1
    return output

#s1="rover"; s2="river"; print(hamming(s1,s2))

binsLog = np.logspace(-2,2,plotbin_size)
b = 'pt'
toP = {k:[] for k in sorters}
toP2 = {k:[] for k in sorters}
meanHF = {k:[] for k in sorters}
semHF = {k:[] for k in sorters}
for s in sorters:
    for rr in recs_names:
        toP[s].extend(np.asarray(HF_counts[b][s][rr]))
        toP2[s].extend(np.asarray(FR_c[b][s][rr]))
bins = np.linspace(0,10,10)
ri = 1 # recording index
for n,s in enumerate(sorters):
    for bi in range(len(binsLog)-1):
        temp = np.asarray(toP[s])[(toP2[s]>binsLog[bi]) & (toP2[s]<=binsLog[bi+1])]
        temp = temp[~np.isinf(temp)]
        meanHF[s].append(np.nanmean(temp))
        semHF[s].append(stats.sem(temp, nan_policy='omit'))
    meanHF[s] = np.asarray(meanHF[s])
    semHF[s] = np.asarray(semHF[s])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f90abca795d9> in <module>
#      22     ii.append(i['studyName'])
#      23 ii = np.array(ii)
# ---> 24 spike_trains = [sorting.get_unit_spike_train(unit_id=uid) for uid in unit_ids]
#      25
#      26 def calculate_entropies_counts(sorting, method, sampling_frequency, binSec=0.5):
#
# NameError: name 'unit_ids' is not defined

# %%
output, fr, isi = calculate_entropies_counts(sorting, method=y, sampling_frequency=30000,
                                           binSec=0.5)
len(fr)
# Out:
# 24

# %%
HF_counts['pt'].keys()
def hamming(ST1,ST2):
    output=0
    if len(ST1)!=len(ST2):
        print("Spike trains are not equal")
    else:
        for x,(i,j) in enumerate(zip(ST1,ST2)):
            if i!=j:
                print(f'char not math{i,j}in {x}')
                output+=1
    return output

for key, value in HF_counts['pt'].items():
    
    print (key, value)
    
ham_HF = HF_counts['pt'].items()
for k in ham_HF:
        for x in ham_HF[1]:
            # whatever with k, x
# Out:
# HerdingSpikes2 {'2014_11_25_Pair_3_0': [1.0902183127032046, 1.041788575884254, 0.9672201242385706, 1.102897317170527, 1.0607931498305856, 1.0325423625891919, 1.0900841737758111, 1.0193918613488184, 1.0133916904946028, 1.0164568721012814, 1.0130121963489407, 1.0376515455977056, 1.0129140177630145, 1.0238872728126311, 1.0250816279664043, 1.0233084044604914, 0.984670525766259, 0.9481461940705024, 1.0298826131784584, 1.0283591747156038, 1.0266214400589828, 0.9434566710627741, 1.0443617565352252, 0.9980723550455018], '2015_09_03_Pair_9_0A': [1.0730563508510358, 1.0017426867457102, 0.9478732397029965, 0.8565865727007396, 1.0330860132975401, 1.056938232577935, 1.0110583080687492, 1.034125272714365, 1.0311136648728119, 0.9401083399566412, 1.043966908087354, 0.9993226015368908, 1.0090967667329487, 0.9951563582159132, 1.0696643998340933, 1.0334916810542456, 1.0055482519924224, 1.0302800333911704, 1.0651822806399138, 1.0224629279189574, 1.097183769569418, 0.9950179203199344, 1.058282896375546, 1.0101361866284813, 1.0112887420304182, 0.9995556434987368, 0.9972398683361431, 0.9923074816609002, 1.0304260781344516, 0.9832880582203186, 1.0055348667637307, 1.0266879795926893, 1.0176940135239863, 0.9988053979732627, 0.9721847994368356, 0.9914187864320463, 1.0181525013989607, 1.0060940950169428, 1.0344116292471388, 1.017208560176511, 1.0150018278523527, 0.9997228703994395, 1.0191981850981242, 1.0185287409213877, 0.9763867518947479, 0.9987164850495532, 1.0055109446102504, 1.022521378970306, 1.0081812808342356, 1.0326893081967914, 1.0275611174663433, 1.029409867679455, 1.0078061152592663, 1.0079177795869843, 0.9997663849670341, 1.0313024287172192, 0.9880689687338281, 1.0180715292210776, 1.0355445801062, 1.0108934690018343, 0.9688854871954249, 1.0146738340983485, 1.0674282143650298, 1.0045693756645955, 1.03609331291099, 0.9888064877970367, 1.0143078034543147, 1.0053837730071167, 1.0116714652554935, 0.9246702165960395, 1.022821666143534, 0.9871783038705798, 1.1371938024449706, 0.9995086535679067, 0.9954204811988548, 1.0093334236260014, 1.015250037670882, 1.0216942717304434, 1.0030191966271893, 0.9884447688049176, 0.9557857655989036, 0.9848125546840323, 1.0098979755068962, 1.0199797568572333, 0.9911470159439835], '2015_09_03_Pair_9_0B': [1.0803036415612595, 1.0629490221344897, 0.969525677554544, 1.0023393757143726, 0.9880743342223489, 1.0567707447068264, 0.9469676230
 1.0244896283775051, 0.9275219093404197, 1.0206344868235513, 0.9815369038846878, 1.0325362226143464, 0.9633163900386551, 1.082937560900135, 0.9951464042185602, 1.0326676470434055, 0.8964059933762887, 1.0262176533812941, 0.8903757769460036, 1.0447052508321901, 0.99552990882776, 1.0516806414280013, 1.0576907377591993, 1.1379351033918341, 0.9960330986955704], '2015_09_03_Pair_9_0B': [1.0641765892258614, 1.0399971446665477, 1.0103035181662858, 1.1445469644697028, 1.1109663466431894, 0.9055788172401432, 1.1313641296504655, 0.9868128143963031, 1.0674318296366838, 1.0842618923183573, 1.0426920362069059, 1.018977571412092, 1.0704654700194405, 0.9867951896463452, 1.0097313532778704, 0.9713468693544774, 1.0468395737832834, 0.9370466727215222, 1.0999420946936922, 0.9561910342368162, 1.0072644531471862, 1.0100402527540588, 1.062934856929903, 0.9339429946698778, 1.0041874091581784, 1.1156711649708728, 1.0031120145805557, 0.9625741494061738, 0.9793928952646583, 0.9327327050379389, 0.9385870369079573, 1.0530992476082304, 1.0430861280308366, 1.0727708115964572, 1.0364984245122315, 0.9460202658727306, 1.0765293853692044, 1.1169523558209773, 1.0790204217109443, 1.1242415131457775, 0.9917243280932518, 0.965316661189708, 1.1060820609752318, 1.0856106080134689, 1.0108931963267758, 1.1210372595684925, 1.0610273432707908, 1.033756384417291, 0.978558746493021, 1.0420866619040625, 1.1399578405140596, 1.076972118021043, 1.0200105121629524, 0.9781510019091202, 0.9827246159663838, 1.0181849621949164, 1.0020658271316458, 1.1028461318627816, 1.034869148826546, 1.0407395716673102, 0.9306896509700766, 1.0089773003628688, 0.9950493547946121, 1.0983169820461562, 1.0388265079934218, 1.0484117454685475, 1.0451485599480195, 0.9998498573632448, 1.0904365088975758, 1.0069815570967695, 1.0340856507839113, 0.9323162320520642, 0.9902042597945243, 1.1553664347437014, 1.032738540787089], 'c14': [0.9903 ...
# Tridesclous {'2014_11_25_Pair_3_0': [], '2015_09_03_Pair_9_0A': [], '2015_09_03_Pair_9_0B': [], 'c14': [], 'c16': [], 'c19': [], 'c21': [], 'c24': [], 'c26': [], 'c27': [], 'c28': [], 'c42': [], 'c44': [], 'c45': [], 'c46': []}

# %%
def hamming(ST1,ST2):
    output=0
    if len(ST1)!=len(ST2):
        print("Spike trains are not equal")
    else:
        for x,(i,j) in enumerate(zip(ST1,ST2)):
            if i!=j:
               # print(f'char not math{i,j}in {x}')
                output+=1
    return output

#s1="rover"
#s2="river"
#print(hamming(s1,s2))

# %%
for k in HF_counts['pt']:
    for x in HF_counts['pt'][k]:
        out[x] = hamming(fr,binSec,N)
    return np.mean(out)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-79eaedce284f> in <module>
#       1 ham_HF = HF_counts['pt'].items()
# ----> 2 ham_HF[1]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
[hamming(i, j) for i in HF_counts['pt']['HerdingSpikes2'] for j in HF_counts['pt']['HerdingSpikes2']]
len(output)
# Out:
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# Spike trains are not equal
# 342
